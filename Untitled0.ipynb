# %% [markdown]
# <a href="https://colab.research.google.com/github/haritha544/DA_Rcodefiles/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/ds_salaries.csv")

# %%
df.head
# Out:
# <bound method NDFrame.head of      Unnamed: 0  work_year experience_level employment_type  \
# 0             0       2020               MI              FT
# 1             1       2020               SE              FT
# 2             2       2020               SE              FT
# 3             3       2020               MI              FT
# 4             4       2020               SE              FT
# ..          ...        ...              ...             ...
# 602         602       2022               SE              FT
# 603         603       2022               SE              FT
# 604         604       2022               SE              FT
# 605         605       2022               SE              FT
# 606         606       2022               MI              FT
#
#                       job_title  salary salary_currency  salary_in_usd  \
# 0                Data Scientist   70000             EUR          79833
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
df.size
# Out:
# 7284

# %%
df.shape
# Out:
# (607, 12)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#        'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#        'employee_residence', 'remote_ratio', 'company_location',
#        'company_size'],
#       dtype='object')

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=607, step=1),
#  Index(['Unnamed: 0', 'work_year', 'experience_level', 'employment_type',
#         'job_title', 'salary', 'salary_currency', 'salary_in_usd',
#         'employee_residence', 'remote_ratio', 'company_location',
#         'company_size'],
#        dtype='object')]

# %%
df.values
# Out:
# array([[0, 2020, 'MI', ..., 0, 'DE', 'L'],
#        [1, 2020, 'SE', ..., 0, 'JP', 'S'],
#        [2, 2020, 'SE', ..., 50, 'GB', 'M'],
#        ...,
#        [604, 2022, 'SE', ..., 0, 'US', 'M'],
#        [605, 2022, 'SE', ..., 100, 'US', 'M'],
#        [606, 2022, 'MI', ..., 100, 'US', 'L']], dtype=object)

# %%
df.ndim
# Out:
# 2

# %%
df.shape[0]
# Out:
# 607

# %%
df.shape[1]
# Out:
# 12

# %%
df.describe()
# Out:
#        Unnamed: 0    work_year        salary  salary_in_usd  remote_ratio
# count  607.000000   607.000000  6.070000e+02     607.000000     607.00000
# mean   303.000000  2021.405272  3.240001e+05  112297.869852      70.92257
# std    175.370085     0.692133  1.544357e+06   70957.259411      40.70913
# min      0.000000  2020.000000  4.000000e+03    2859.000000       0.00000
# 25%    151.500000  2021.000000  7.000000e+04   62726.000000      50.00000
# 50%    303.000000  2022.000000  1.150000e+05  101570.000000     100.00000
# 75%    454.500000  2022.000000  1.650000e+05  150000.000000     100.00000
# max    606.000000  2022.000000  3.040000e+07  600000.000000     100.00000

# %%
df.max()
# Out:
# Unnamed: 0                             606
# work_year                             2022
# experience_level                        SE
# employment_type                         PT
# job_title             Staff Data Scientist
# salary                            30400000
# salary_currency                        USD
# salary_in_usd                       600000
# employee_residence                      VN
# remote_ratio                           100
# company_location                        VN
# company_size                             S
# dtype: object

# %%
df.min()
# Out:
# Unnamed: 0                                        0
# work_year                                      2020
# experience_level                                 EN
# employment_type                                  CT
# job_title             3D Computer Vision Researcher
# salary                                         4000
# salary_currency                                 AUD
# salary_in_usd                                  2859
# employee_residence                               AE
# remote_ratio                                      0
# company_location                                 AE
# company_size                                      L
# dtype: object

# %%
df.mean()
# Out:
# <ipython-input-7-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0          303.000000
# work_year          2021.405272
# salary           324000.062603
# salary_in_usd    112297.869852
# remote_ratio         70.922570
# dtype: float64

# %%
df.std()
# Out:
# <ipython-input-8-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Unnamed: 0       1.753701e+02
# work_year        6.921330e-01
# salary           1.544357e+06
# salary_in_usd    7.095726e+04
# remote_ratio     4.070913e+01
# dtype: float64

# %%
df.mean()
# Out:
# <ipython-input-10-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Unnamed: 0          303.000000
# work_year          2021.405272
# salary           324000.062603
# salary_in_usd    112297.869852
# remote_ratio         70.922570
# dtype: float64

# %%
df.head(50)
# Out:
#     Unnamed: 0  work_year experience_level employment_type  \
# 0            0       2020               MI              FT
# 1            1       2020               SE              FT
# 2            2       2020               SE              FT
# 3            3       2020               MI              FT
# 4            4       2020               SE              FT
# 5            5       2020               EN              FT
# 6            6       2020               SE              FT
# 7            7       2020               MI              FT
# 8            8       2020               MI              FT
# 9            9       2020               SE              FT
# 10          10       2020               EN              FT
# 11          11       2020               MI              FT
# 12          12       2020               EN              FT
# 13          13       2020               MI              FT
# 14          14       2020               MI              FT
# ...

# %%
df_mean = df.head(50).mean()
# Out:
# <ipython-input-13-66e1e2029efb>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_mean = df.head(50).mean()

# %%
df.work_year
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 602    2022
# 603    2022
# 604    2022
# 605    2022
# 606    2022
# Name: work_year, Length: 607, dtype: int64

# %%
df['work_year']
# Out:
# 0      2020
# 1      2020
# 2      2020
# 3      2020
# 4      2020
#        ...
# 602    2022
# 603    2022
# 604    2022
# 605    2022
# 606    2022
# Name: work_year, Length: 607, dtype: int64

# %%
df[['work_year']]
# Out:
#      work_year
# 0         2020
# 1         2020
# 2         2020
# 3         2020
# 4         2020
# ..         ...
# 602       2022
# 603       2022
# 604       2022
# 605       2022
# 606       2022
#
# [607 rows x 1 columns]

# %%
df.iloc[1:4,2:7]
# Out:
#   experience_level employment_type                   job_title  salary  \
# 1               SE              FT  Machine Learning Scientist  260000
# 2               SE              FT           Big Data Engineer   85000
# 3               MI              FT        Product Data Analyst   20000
#
#   salary_currency
# 1             USD
# 2             GBP
# 3             USD

# %%
df[['job_title','salary']].agg(['min','max','median'])
# Out:
# <ipython-input-20-4d10e1b94148>:1: FutureWarning: ['job_title'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   df[['job_title','salary']].agg(['min','max','median'])
#                             job_title      salary
# min     3D Computer Vision Researcher      4000.0
# max              Staff Data Scientist  30400000.0
# median                            NaN    115000.0
